# %%
import pandas as pd
import numpy as np

# %%
# Files to Load
jn1_data_to_load = "/Users/benjaminshelburn/Desktop/Jetnet_Project/TemplateNonSDCustomer1.csv"
jn2_data_to_load = "/Users/benjaminshelburn/Desktop/Jetnet_Project/TemplateNonSDCustomer2.csv"
jn3_data_to_load = "/Users/benjaminshelburn/Desktop/Jetnet_Project/TemplateNonSDCustomer3.csv"
jn4_data_to_load = "/Users/benjaminshelburn/Desktop/Jetnet_Project/TemplateNonSDCustomer4.csv"

# %%
# Read the Jetnet Data
jn1_data_df = pd.read_csv(jn1_data_to_load)
jn2_data_df = pd.read_csv(jn2_data_to_load)
jn3_data_df = pd.read_csv(jn3_data_to_load)
jn4_data_df = pd.read_csv(jn4_data_to_load)

# %%
jn_masterdata_df = pd.concat([jn1_data_df, jn2_data_df, jn3_data_df, jn4_data_df], ignore_index=True)

# %%
titles_df = jn_masterdata_df['CONTACTTITLE'].unique()
titles_df
# Out:
# array(['Manager', 'President', nan, 'Chairman', 'General Manager',
#        'Director of Maintenance', 'Chief Pilot', 'President & CEO',
#        'Chief Administrative & Financial Officer',
#        'Sales Readiness Manager', 'Chairman, President & CEO',
#        'Senior Vice President', 'Member', 'Member/Manager',
#        'President & Chief Pilot', 'Owner', 'Managing Partner',
#        'Sales Coordinator', 'Director', 'Regional Sales Director',
#        'Aviation Department Manager',
#        'Director of Operations & Chief Pilot', 'CEO', 'Vice President',
#        'Director of Aviation', 'Sr. Vice President & General Counsel',
#        'Managing Director', 'Chief Financial Officer',
#        'Executive Director', 'Co-Manager', 'Aircraft Sales',
#        'Strategic Accounts Manager', 'CEO & Founder', 'Managing Member',
#        'Sales Manager', 'Flight Department Manager',
#        'President & Manager', 'Owner & Chief Pilot',
# ...
